# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# ===== Cấu hình Chrome =====
chrome_options = Options()
chrome_options.add_argument("--headless")  # bỏ nếu muốn xem trình duyệt
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option('useAutomationExtension', False)

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)
driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")

# ===== Danh sách URL muốn crawl =====
urls = {
    "Điện thoại": "https://www.lazada.vn/catalog/?q=điện%20thoại",
    "Quần áo": "https://www.lazada.vn/catalog/?q=quần%20áo", 
    "Tủ lạnh": "https://www.lazada.vn/catalog/?q=tủ%20lạnh",
    "Tivi": "https://www.lazada.vn/catalog/?q=ti%20vi"
}

# ===== Hàm scroll để load thêm sản phẩm =====
def scroll_and_count():
    """Scroll và đếm sản phẩm có giá"""
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)
    driver.execute_script("window.scrollBy(0, -200);")
    time.sleep(2)
    
    # Đếm sản phẩm có giá hợp lệ
    products = driver.find_elements(By.CSS_SELECTOR, "div.RfADt")
    valid_count = 0
    
    for product in products:
        try:
            # Kiểm tra nhanh xem có giá không
            full_text = product.text
            if "₫" in full_text and any(char.isdigit() for char in full_text):
                valid_count += 1
        except:
            continue
    
    return len(products), valid_count

# ===== Hàm crawl dữ liệu 1 URL với đảm bảo tối thiểu =====
def crawl_lazada(url, category, min_items=80):
    print(f"🔍 Đang crawl {category} (cần tối thiểu {min_items} sản phẩm có giá)...")
    driver.get(url)
    time.sleep(5)
    
    data = []
    scroll_attempts = 0
    max_attempts = 8  # Tăng số lần thử
    last_valid_count = 0
    no_progress_count = 0
    
    while len(data) < min_items and scroll_attempts < max_attempts:
        scroll_attempts += 1
        print(f"  🔄 Lần scroll thứ {scroll_attempts}...")
        
        # Scroll và đếm
        total_products, estimated_valid = scroll_and_count()
        print(f"  📊 Tổng sản phẩm: {total_products}, ước tính có giá: {estimated_valid}")
        
        # Kiểm tra tiến trình
        if estimated_valid <= last_valid_count:
            no_progress_count += 1
            if no_progress_count >= 3:
                print(f"  ⚠️  Không có tiến trình trong 3 lần scroll, dừng lại")
                break
        else:
            no_progress_count = 0
        
        last_valid_count = estimated_valid
        
        # ===== Thay thế logic xử lý products bằng processed_index =====
        processed_index = 0
        products = driver.find_elements(By.CSS_SELECTOR, "div.RfADt")
        while len(data) < min_items:
            # nếu đã duyệt hết products thì scroll thêm và cập nhật lại
            if processed_index >= len(products):
                # scroll thêm 1 lần để load product mới
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(2)
                products = driver.find_elements(By.CSS_SELECTOR, "div.RfADt")
                # nếu không có thêm phần tử thì dừng vòng lặp
                if processed_index >= len(products):
                    print("  ⚠️ Không load thêm product mới, dừng việc lấy thêm.")
                    break

            # lấy product hiện tại và tăng processed_index (đảm bảo không lặp)
            product = products[processed_index]
            processed_index += 1

            try:
                # đảm bảo visible để lazy-load giá
                try:
                    driver.execute_script("arguments[0].scrollIntoView({block:'center'});", product)
                except:
                    pass
                time.sleep(0.3)

                # Lấy tên
                try:
                    name_element = product.find_element(By.CSS_SELECTOR, "a")
                    name = name_element.get_attribute("title") or name_element.text.strip()
                    if not name:
                        name = product.text.strip().split('\n')[0][:100]
                except:
                    name = "N/A"

                # Lấy giá (giữ nguyên các phương pháp của bạn)
                price = "N/A"
                price_selectors = [
                    ".//following::span[@class='ooOxS'][1]",
                    ".//following::span[contains(@class, 'currency')]",
                    ".//following::span[contains(text(), '₫')]",
                    ".//span[contains(@class, 'price')]",
                    ".//span[contains(text(), '₫')]",
                    ".//following-sibling::*//span[contains(text(), '₫')]",
                    ".//ancestor::*//span[contains(text(), '₫')]"
                ]
                for selector in price_selectors:
                    try:
                        price_element = product.find_element(By.XPATH, selector)
                        price_text = price_element.get_attribute("textContent") or price_element.text
                        price_text = price_text.strip()
                        if price_text and "₫" in price_text and any(c.isdigit() for c in price_text):
                            price = price_text
                            break
                    except:
                        continue

                # fallback: tìm trong text node nếu selector không có
                if price == "N/A":
                    try:
                        full_text = product.get_attribute("textContent") or product.text or ""
                        import re
                        m = re.search(r'[\d\.,\s]+₫', full_text)
                        if m:
                            price = m.group().strip()
                    except:
                        pass

                # sold count (giữ nguyên)
                try:
                    sold_selectors = [
                        ".//following::span[contains(text(),'Đã bán')]",
                        ".//span[contains(text(),'Đã bán')]",
                        ".//following::*[contains(text(),'Đã bán')]"
                    ]
                    sold_count = "N/A"
                    for selector in sold_selectors:
                        try:
                            sold_element = product.find_element(By.XPATH, selector)
                            sold_count = sold_element.get_attribute("textContent") or sold_element.text
                            sold_count = sold_count.strip()
                            break
                        except:
                            continue
                except:
                    sold_count = "N/A"

                # Thêm nếu có giá
                if price != "N/A" and price.strip() and "₫" in price:
                    data.append({
                        "Category": category,
                        "Name": name,
                        "Price": price,
                        "SoldCount": sold_count
                    })
                    print(f"  ✅ SP {len(data)}: {name[:40]}... - {price}")

                else:
                    print(f"  ⚠️ Bỏ qua product idx {processed_index}: không có giá hợp lệ")

            except Exception as e:
                print(f"  ❌ Lỗi khi xử lý product idx {processed_index}: {e}")
                continue
        
        print(f"  📈 Hiện có {len(data)}/{min_items} sản phẩm hợp lệ")
        
        # Nếu đã đủ, thoát
        if len(data) >= min_items:
            print(f"  🎉 Đã đủ {min_items} sản phẩm!")
            break
            
        time.sleep(3)
    
    final_count = len(data)
    if final_count >= min_items:
        print(f"  ✅ [{category}] Thành công: {final_count} sản phẩm")
    else:
        print(f"  ⚠️  [{category}] Chỉ lấy được {final_count}/{min_items} sản phẩm")
    
    return data

# ===== Crawl toàn bộ URL =====
all_data = []
min_products_per_category = 80

for category, url in urls.items():
    results = crawl_lazada(url, category, min_items=min_products_per_category)
    all_data.extend(results)
    print(f"🔄 Nghỉ 5 giây trước khi crawl category tiếp theo...\n")
    time.sleep(5)

# ===== Lưu ra Excel =====
if all_data:
    df = pd.DataFrame(all_data)
    df.to_excel("lazada_products_minimum_80.xlsx", index=False)
    print(f"✅ Crawl xong! Tổng cộng {len(all_data)} sản phẩm được lưu vào lazada_products_minimum_80.xlsx")
    
    # Thống kê chi tiết
    print("\n📈 Thống kê theo danh mục:")
    category_stats = df.groupby('Category').size()
    total_categories = len(category_stats)
    success_categories = sum(1 for count in category_stats.values() if count >= min_products_per_category)
    
    for cat, count in category_stats.items():
        status = "✅" if count >= min_products_per_category else "⚠️ "
        print(f"  {status} {cat}: {count} sản phẩm")
    
    print(f"\n📊 Tổng kết: {success_categories}/{total_categories} danh mục đạt tối thiểu {min_products_per_category} sản phẩm")
    
    # Kiểm tra giá hợp lệ
    valid_prices = df[df['Price'] != 'N/A']
    print(f"💰 Sản phẩm có giá hợp lệ: {len(valid_prices)}/{len(df)} ({len(valid_prices)/len(df)*100:.1f}%)")
    
else:
    print("❌ Không thu thập được dữ liệu nào!")

driver.quit()
# Out:
# 🔍 Đang crawl Điện thoại (cần tối thiểu 80 sản phẩm có giá)...
#   🔄 Lần scroll thứ 1...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ✅ SP 1: Điện thoại realme C61 RAM 6GB ROM 128GB ... - 719.000 ₫
#   ✅ SP 2: Điện thoại TECNO SPARK 40 (8GB/256GB) - ... - 4.140.000 ₫
#   ✅ SP 3: Điện thoại TECNO SPARK 40 (6GB/128GB) - ... - 3.440.000 ₫
#   ✅ SP 4: Điện thoại thông minh Xia0mi Redmi A5- 4... - 679.000 ₫
#   ✅ SP 5: Galax A55 điện thoại 16GB RAM +1TB ROM M... - 300.000 ₫
#   ✅ SP 6: Điện thoại OPP0 A5i Pr0 8GB/128GB | Thiế... - 725.000 ₫
#   ✅ SP 7: Điện Thoại Kyocera Torque G05 - 5G TD-LT... - 2.190.000 ₫
#   ✅ SP 8: Điện thoại Xiaomi Mi 11 Lite 5G Ram 8GB ... - 278.000 ₫
#   ✅ SP 9: Galax S24 Ultra điện thoại gốc mớii 16GB... - 300.000 ₫
#   ✅ SP 10: Điện thoại A.Oppo A97 5G 8GB/256GB Pin 5... - 1.975.000 ₫
#   ✅ SP 11: Galax S24 ultra điện thoại 16GB RAM +1TB... - 300.000 ₫
#   ✅ SP 12: Điện thoại realme 13+ 5G RAM 8GB ROM 256... - 955.000 ₫
#   ✅ SP 13: Galax S24 điện thoại gốc mớii 16GB RAM +... - 1.199.000 ₫
#   ✅ SP 14: Galax A73 điện thoại gốc mớii 16GB RAM +... - 1.199.000 ₫
#   ✅ SP 15: Galax S24 điện thoại 16GB RAM +1TB ROM M... - 1.199.000 ₫
#   ✅ SP 16: I16 Pro Max điên thoại Full HD 16GB RAM ... - 1.199.000 ₫
#   ✅ SP 17: [COD] Điện thoại 5g giá rẻ I16 Pro Max T... - 1.199.000 ₫
#   ✅ SP 18: Galax A55 điên thoại gia rẻ Full HD 16GB... - 1.199.000 ₫
#   ✅ SP 19: Oqqo reno9 điên thoại Full HD 16GB RAM +... - 300.000 ₫
#   ✅ SP 20: Điện Thoại Oukitel WP38 4G | Pin 10600mA... - 1.227.500 ₫
#   ✅ SP 21: đt siêu rẻ Vi xử lý 10 nhân điện thoại g... - 1.271.423 ₫
#   ✅ SP 22: Điện thoại dưới 2 triệuHàng mới về đt si... - 1.122.211 ₫
#   ✅ SP 23: Galax A73 điên thoại gia rẻ Full HD 16GB... - 300.000 ₫
#   ✅ SP 24: Galax S24 Ultra điện thoại chính hãng gi... - 300.000 ₫
#   ✅ SP 25: điện thoại 0PP0 F11 Ram 8gb/ 256gB máy đ... - 1.699.000 ₫
#   ✅ SP 26: Sony Xperia 5 iii (sọc màn )... - 250.000 ₫
#   ✅ SP 27: Điện thoại mi Mi 15 Utra Cấu hình mạnh, ... - 1.600.000 ₫
#   ✅ SP 28: Điện thoại di động hoàn toàn mới oqqo Re... - 300.000 ₫
#   ✅ SP 29: (Mua kèm phụ kiện giảm thêm 30k) Điện th... - 2.510.000 ₫
#   ✅ SP 30: Galax A73 điện thoại 16GB RAM +1TB ROM M... - 1.199.000 ₫
#   ✅ SP 31: Điện thoại Redmi_n0te 13pr Ram 8GB/128GB... - 1.200.000 ₫
#   ✅ SP 32: Galax Oqqo Reno13 điên thoại gia rẻ Full... - 1.199.000 ₫
#   ✅ SP 33: SAMSUNG A31  6G/128GGIÁ MỀM -SIÊU ĐẸP CH... - 1.850.000 ₫
#   ✅ SP 34: [COD] Điện thoại 5g giá rẻ Oqqo Reno13 T... - 1.199.000 ₫
#   ✅ SP 35: Điện thoại Y.Vivo Y11 - 2sim Ram 6G/128G... - 955.000 ₫
#   ✅ SP 36: Điện thoại Masstel Fami 60s 4G dùng cho ... - 699.000 ₫
#   ✅ SP 37: Điện thoại A.OPPO Reno7 Pro 5G (12GB 256... - 2.890.000 ₫
#   ✅ SP 38: Điện thoại Redmi 9T Ram 6GB bộ nhớ 128GB... - 1.590.000 ₫
#   ✅ SP 39: Galax S24 Ultra điên thoại gia rẻ Full H... - 1.639.000 ₫
#   ✅ SP 40: NEW A55 điện thoại di động 6.8 inch Màn ... - 1.198.000 ₫
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 2...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 3...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ⚠️  Không có tiến trình trong 3 lần scroll, dừng lại
#   ⚠️  [Điện thoại] Chỉ lấy được 40/80 sản phẩm
# 🔄 Nghỉ 5 giây trước khi crawl category tiếp theo...
#
# 🔍 Đang crawl Quần áo (cần tối thiểu 80 sản phẩm có giá)...
#   🔄 Lần scroll thứ 1...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ✅ SP 1: Bộ quần áo thể thao nam nữ Sport chất th... - 68.200 ₫
#   ✅ SP 2: Bộ đồ thể thao Nam Nữ Mùa Hè Chất xốp vâ... - 129.000 ₫
#   ✅ SP 3: Đồ ngủ nữ pijama mặc nhà bộ ngủ hoạt hìn... - 19.000 ₫
#   ✅ SP 4: bộ dài tay thun lạnh mikky mom siêu mịn ... - 29.000 ₫
#   ✅ SP 5: (MẪU MỚI ) Sét bộ áo thun cổ tròn nữ kèm... - 29.000 ₫
#   ✅ SP 6: Set bộ mặc nhà . LỬNG CÁNH TIÊN MÀU Size... - 45.000 ₫
#   ✅ SP 7: Bộ quần áo nam mùa hè DSQ loang, chất th... - 95.000 ₫
#   ✅ SP 8: (SÉT MỚI) Sét bộ áo thun cổ tròn phối qu... - 35.000 ₫
#   ✅ SP 9: set bộ tay ngắn quần kẻ thời trang siêu ... - 82.000 ₫
#   ✅ SP 10: SÉT ÁO MẦM LÁ KHÓC KÈM QUẦN KẺ RẤT DỄ TH... - 33.333 ₫
#   ✅ SP 11: ĐỒ LAM ĐI CHÙA CHO BÉ TRAI - MẪU ĐỒ BÉ T... - 110.000 ₫
#   ✅ SP 12: [3 SIZE 45-70KG) Đồ bộ LỤA ĐÙI CHẤM BI C... - 49.000 ₫
#   ✅ SP 13: [3 size 46-70kg] Đồ bộ LỤA ĐÙI CHẤM BI M... - 49.000 ₫
#   ✅ SP 14: [3 size 46-70KG] Đồ bộ LỬNG LỤA BÔNG MÀU... - 57.200 ₫
#   ✅ SP 15: [2 SIZE 45-68KG TÙY CHIỀU CAO] ĐỒ BỘ THU... - 36.000 ₫
#   ✅ SP 16: (2 Size 50-65Kg) SET THUN LẠNH Lửng LỬNG... - 39.000 ₫
#   ✅ SP 17: SET BỘ TĂM LẠNH TÀ CHÉO THỜI TRANG SIÊU ... - 89.000 ₫
#   ✅ SP 18: ĐỒ BỘ ĐÙI TRƠN THUN TĂM THỜI TRANG 3 siz... - 69.000 ₫
#   ✅ SP 19: [2 SIZE 45-68KG TÙY CHIỀU CAO] ĐỒ BỘ MẪU... - 38.000 ₫
#   ✅ SP 20: 💝Top bán chạy💝 BỘ QUẦN ÁO TRÁI CÂY ĐI BI... - 40.000 ₫
#   ✅ SP 21: [3 size 46-70KG] Đồ bộ LỤA ĐÙI 2 NƠ DỄ T... - 65.000 ₫
#   ✅ SP 22: [3 size 46-70KG] Đồ bộ LỤA LỬNG TIỂU THƯ... - 63.000 ₫
#   ✅ SP 23: CÓ SIZE 70KG ĐỒ BỘ ĐÙI THUN ĐŨA, ĐÙI CON... - 63.000 ₫
#   ✅ SP 24: CÓ SIZE 68KG SET Đồ bộ LỬNG BÔNG MÀU VẢI... - 54.000 ₫
#   ✅ SP 25: Combo 2 bộ mặc nhà thun cotton tay ngắn ... - 49.000 ₫
#   ✅ SP 26: Set Bộ Trung Niên, Đồ Bộ Nữ, Áo Cổ Vest,... - 174.600 ₫
#   ✅ SP 27: [2 SIZE 45-68KG TÙY CHIỀU CAO] ĐỒ BỘ THU... - 39.000 ₫
#   ✅ SP 28: SET BỘ THU ĐÔNG CỔ VUÔNG TAY DÀI XINH XẮ... - 89.000 ₫
#   ✅ SP 29: set bộ thun lạnh 2 dây cao cấp đồ bộ nữ ... - 19.000 ₫
#   ✅ SP 30: FREESIZE 45-58KG TÙY CHIỀU CAO SET ĐỒ BỘ... - 39.000 ₫
#   ✅ SP 31: CÓ SIZE 68KG Đồ bộ LỤA ĐÙI BÔNG NHÍ ĐÙI ... - 49.000 ₫
#   ✅ SP 32: Set đồ nữ sang chảnh áo cổ vuông ph... - 75.000 ₫
#   ✅ SP 33: [3 size 46-65KG] Đồ bộ LỤA LỬNG BÔNG MÀU... - 59.900 ₫
#   ✅ SP 34: ĐỒ BỘ THUN PARI  , TĂM GẤU MẪU MỚI TINH ... - 79.000 ₫
#   ✅ SP 35: [Bigsize]Set đồ nữ chấm bi tay cánh tiên... - 76.000 ₫
#   ✅ SP 36: [2 SIZE 45-68KG TÙY CHIỀU CAO] ĐỒ BỘ MẪU... - 39.000 ₫
#   ✅ SP 37: SET BỘ CAO CẤP THUN GÂN 2 SIZE 48-70KG T... - 69.000 ₫
#   ✅ SP 38: Đồ bộ pijama ANH MỸ chất liệu lụa xước á... - 99.000 ₫
#   ✅ SP 39: Đồ bộ THUN LẠNH MÁT CỔ TIM MẶC NHÀ SEXY ... - 39.000 ₫
#   ✅ SP 40: [3 size 42-70KG] Đồ bộ LATIN NƠ TRƯỚC NG... - 89.000 ₫
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 2...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 3...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ⚠️  Không có tiến trình trong 3 lần scroll, dừng lại
#   ⚠️  [Quần áo] Chỉ lấy được 40/80 sản phẩm
# 🔄 Nghỉ 5 giây trước khi crawl category tiếp theo...
#
# 🔍 Đang crawl Tủ lạnh (cần tối thiểu 80 sản phẩm có giá)...
#   🔄 Lần scroll thứ 1...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ✅ SP 1: Tủ lạnh sanyo - 140l... - 1.600.000 ₫
#   ✅ SP 2: Tủ lạnh mini 8L 12L 16L  (Hàng sẵn 16L)... - 650.000 ₫
#   ✅ SP 3: Tủ lạnh Hitachi Inverter 464 lít Multi D... - 20.090.000 ₫
#   ✅ SP 4: Tủ lạnh aqua 93 lít nhỉ gọn tiết kiệm đi... - 1.350.000 ₫
#   ✅ SP 5: Tủ lạnh mini 2 cánh có tích hợp ngăn đá ... - 2.590.000 ₫
#   ✅ SP 6: Tủ lạnh Mini 2 cánh gia đình , tủ lạnh m... - 2.650.000 ₫
#   ✅ SP 7: Tủ lạnh 2 ngăn cao cấp tiết kiện điện, n... - 1.800.000 ₫
#   ✅ SP 8: tủ lạnh sanyou 110 lít làm lạnh và đông ... - 1.500.000 ₫
#   ✅ SP 9: Tủ lạnh mini 2 cánh siêu tiết kiệm điện,... - 2.590.000 ₫
#   ✅ SP 10: Tủ Mát Cửa Kính Low-E Sanden 394 Lít Inv... - 16.610.000 ₫
#   ✅ SP 11: Tủ lạnh LG Inverter 332 lít LBD33BLM - B... - 10.390.000 ₫
#   ✅ SP 12: Tủ lạnh mini gia đình tích hợp hai ngăn ... - 2.650.000 ₫
#   ✅ SP 13: Tủ lạnh mini, tủ lạnh mini có ngăn đá du... - 2.095.000 ₫
#   ✅ SP 14: Tủ lạnh mini AIPU 86 lít BCD-86L KT 80x4... - 2.299.000 ₫
#   ✅ SP 15: Tủ lạnh Aqua 50 lít AQR-D60FA(BS) (trưng... - 2.390.000 ₫
#   ✅ SP 16: Tủ lạnh mini 2 ngăn cao cấp tiết kiện, n... - 2.590.000 ₫
#   ✅ SP 17: [Chỉ Giao + Lắp Hà Nội] Tủ lạnh Samsung ... - 10.190.000 ₫
#   ✅ SP 18: Tủ Lạnh 2 Cánh 110L ROYALSTAR Làm Đá Lạn... - 3.790.000 ₫
#   ✅ SP 19: Tủ lạnh mini 25L - AN25... - 2.620.000 ₫
#   ✅ SP 20: Tủ mát 600lit lạnh tốt đã qua sử dụng lạ... - 6.199.000 ₫
#   ✅ SP 21: Tủ lạnh Aqua Inverter 236 lít AQR-T260FA... - 4.890.000 ₫
#   ✅ SP 22: [Chỉ Giao + Lắp Hà Nội] Tủ lạnh Samsung ... - 13.090.000 ₫
#   ✅ SP 23: Tủ Lạnh 2 Cánh110L Tủ Lạnh Làm Đá lạnh C... - 3.790.000 ₫
#   ✅ SP 24: Tủ lạnh Sharp Inverter 362 lít Multi Doo... - 12.890.000 ₫
#   ✅ SP 25: Tủ lạnh sanyou 93 lít tiết kiệm điện [ L... - 1.400.000 ₫
#   ✅ SP 26: Tủ lạnh mini Electrolux UltimateTaste 30... - 3.799.000 ₫
#   ✅ SP 27: Tủ lạnh Toshiba Inverter 253 lít GR-RT32... - 7.699.000 ₫
#   ✅ SP 28: Tủ lạnh sanyo 180lit không bám tuyết đã ... - 1.699.000 ₫
#   ✅ SP 29: TRẢ GÓP 0% - Tủ lạnh Electrolux Inverter... - 15.093.000 ₫
#   ✅ SP 30: Tủ lạnh Funiki 74 lít FR-71CD - Mới 2024... - 2.790.000 ₫
#   ✅ SP 31: Tủ lạnh mini,48L KT 680*370*380mm và tủ ... - 1.900.000 ₫
#   ✅ SP 32: Tủ lạnh Toshiba Inverter 338 lít GR-RT46... - 8.390.000 ₫
#   ✅ SP 33: Tủ lạnh mini 42L 2 cánh, ngăn đông riêng... - 2.590.000 ₫
#   ✅ SP 34: Tủ lạnh 2 ngăn 48 lít thương hiệu làm lạ... - 1.900.000 ₫
#   ✅ SP 35: [SALE SỐC] Tủ lạnh Aqua Inverter 236 lít... - 12.090.000 ₫
#   ✅ SP 36: Tủ lạnh hitachi 200 lít [ LH / ZL 096671... - 2.000.000 ₫
#   ✅ SP 37: Tủ lạnh Sharp SJ-FX630V-ST | Tủ lạnh Sid... - 15.390.000 ₫
#   ✅ SP 38: Tủ lạnh Aqua 90 lít AQR-D100FA(BS) (xả k... - 2.790.000 ₫
#   ✅ SP 39: Tủ lạnh mini,48L KT 680*370*380mm và tủ ... - 1.900.000 ₫
#   ✅ SP 40: Tủ lạnh sharp 180l [LH / ZL 0966717185 ]... - 2.300.000 ₫
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 2...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 3...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ⚠️  Không có tiến trình trong 3 lần scroll, dừng lại
#   ⚠️  [Tủ lạnh] Chỉ lấy được 40/80 sản phẩm
# 🔄 Nghỉ 5 giây trước khi crawl category tiếp theo...
#
# 🔍 Đang crawl Tivi (cần tối thiểu 80 sản phẩm có giá)...
#   🔄 Lần scroll thứ 1...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ✅ SP 1: Smart Tivi20/22/24inch Android Tivi,MÀN ... - 1.099.999 ₫
#   ✅ SP 2: [HCM] Smart Tivi Samsung 4K 55 inch UA55... - 9.690.000 ₫
#   ✅ SP 3: Smart Tivi Toshiba AI 4K 75 inch 75C350R... - 20.999.000 ₫
#   ✅ SP 4: Smart Tivi Android Tivi,MÀN HÌNH 20/22/2... - 1.199.450 ₫
#   ✅ SP 5: Tivi led 24 inch Darling có tích hợp đầu... - 2.330.000 ₫
#   ✅ SP 6: Tivi led 25 inch Asanzo tích hợp đầu thu... - 2.450.000 ₫
#   ✅ SP 7: Thanh lý Smart Tivi Samsung 43inch 4k có... - 3.650.000 ₫
#   ✅ SP 8: Smart Tivi Toshiba AI 4K 65 inch 65C350R... - 13.990.000 ₫
#   ✅ SP 9: Smart Tivi Samsung 4K Crystal UHD 65 inc... - 12.790.000 ₫
#   ✅ SP 10: Ti vi Asanzo Smart 32 inch 32Ex9... - 3.699.000 ₫
#   ✅ SP 11: [MIỄN PHÍ VẬN CHUYỂN] Smart Tivi Samsung... - 3.929.000 ₫
#   ✅ SP 12: Smart ti vi Cooca 43 inch 43S3U... - 4.599.000 ₫
#   ✅ SP 13: Google Tivi Coocaa Full HD 43 Inch 43Z85... - 5.690.000 ₫
#   ✅ SP 14: [TV Mới] Xiaomi TV A 55'' 2026 | Màn hìn... - 9.320.000 ₫
#   ✅ SP 15: Tivi 50" WIFI - 4K - BLUETOOTH - KÈM ĐIỀ... - 5.599.000 ₫
#   ✅ SP 16: Smart Tivi Toshiba Full HD 43 inch 43E31... - 6.990.000 ₫
#   ✅ SP 17: [BẢO HÀNH 24 THÁNG ] SMART TIVI CASPER 3... - 3.518.000 ₫
#   ✅ SP 18: Ti vi asanzo 40S610T2... - 3.599.000 ₫
#   ✅ SP 19: Google Tivi QLED Xiaomi A Pro 4K 75 inch... - 8.567.000 ₫
#   ✅ SP 20: Smart Tivi Xiaomi A2 Full HD 43 inch Chí... - 5.590.000 ₫
#   ✅ SP 21: Tivi 32 inch HXY thương hiệu Nhật Bản th... - 2.750.000 ₫
#   ✅ SP 22: Smart Tivi Xiaomi P1 55 inch Màn Hình Ch... - 8.490.000 ₫
#   ✅ SP 23: Thanh lý Tivi Sony 32inch LCD ảnh đẹp, s... - 1.480.000 ₫
#   ✅ SP 24: Smart Tivi Crystal UHD Samsung 4K 50 inc... - 8.200.000 ₫
#   ✅ SP 25: [SP Mới 2025] Smart Tivi Toshiba 50 inch... - 10.990.000 ₫
#   ✅ SP 26: Smart tivi di động TV-19 màn hình cảm ứn... - 5.390.000 ₫
#   ✅ SP 27: [MODEL 2024][FreeSHIP COD + Lắp Hà Nội] ... - 9.490.000 ₫
#   ✅ SP 28: Smart Tivi Toshiba Full HD 43 inch 43E31... - 5.949.000 ₫
#   ✅ SP 29: [SP Mới 2025] Smart Tivi Toshiba 43 inch... - 9.290.000 ₫
#   ✅ SP 30: Smart TV HD Coocaa 32 Inch 32S3U+ - khôn... - 3.199.000 ₫
#   ✅ SP 31: (hàng trưng bày) Thanh lý Smart Tivi Sam... - 2.900.000 ₫
#   ✅ SP 32: 【UHD 4K】55inch - Smart Google TV TCL 55T... - 7.890.000 ₫
#   ✅ SP 33: Tivi màu cổ 14 inch Sanyo funbox đủ phụ ... - 2.500.000 ₫
#   ✅ SP 34: Tivi Xiaomi A75 75 inch 2025 – 1200Hz/2G... - 12.390.000 ₫
#   ✅ SP 35: Smart Tivi Hisense 40 inch FHD 40A4Q, Gi... - 5.590.000 ₫
#   ✅ SP 36: [BẢO HÀNH 24 THÁNG ] SMART TIVI CASPER 4... - 4.769.000 ₫
#   ✅ SP 37: Smart Tivi 4K UHD 43 Inch UA43AU7002KXXV... - 5.985.000 ₫
#   ✅ SP 38: Smart Tivi Crystal UHD Samsung 4K 50 inc... - 8.500.000 ₫
#   ✅ SP 39: Bản Quốc Tế - ĐIều khiển giọng nói - BH ... - 5.900.000 ₫
#   ✅ SP 40: Tivi Xiaomi 32 inch A Pro Google TV QLED... - 4.990.000 ₫
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 2...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   📈 Hiện có 40/80 sản phẩm hợp lệ
#   🔄 Lần scroll thứ 3...
#   📊 Tổng sản phẩm: 40, ước tính có giá: 0
#   ⚠️  Không có tiến trình trong 3 lần scroll, dừng lại
#   ⚠️  [Tivi] Chỉ lấy được 40/80 sản phẩm
# 🔄 Nghỉ 5 giây trước khi crawl category tiếp theo...
#
# ✅ Crawl xong! Tổng cộng 160 sản phẩm được lưu vào lazada_products_minimum_80.xlsx
#
# 📈 Thống kê theo danh mục:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 236
#     234 category_stats = df.groupby('Category').size()
#     235 total_categories = len(category_stats)
# --> 236 success_categories = sum(1 for count in category_stats.values() if count >= min_products_per_category)
#     238 for cat, count in category_stats.items():
#     239     status = "✅" if count >= min_products_per_category else "⚠️ "
#
# TypeError: 'numpy.ndarray' object is not callable
